# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# from open weather documentation: api.openweathermap.org/data/2.5/find?q=London&units=imperial

url = 'http://api.openweathermap.org/data/2.5/weather?'
api_key = weather_api_key
units = 'imperial'
query = f'{url}&appid={api_key}&units={units}&q='

# response = requests.get(query).json()
# response['name']

City = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []

print(f'Beginning Data Retrieval')
print(f'-----------------------------------')
idx_counter = 0
counter = 1

for idx,city in enumerate(cities, start=1):
    
    try:
    
#         total = len(cities)
        response = requests.get(query + city).json()
        City.append(response['name'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Speed.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        
        if idx_counter > 49:
            idx_counter = 0
            counter = counter + 1
        else:
            idx_counter = idx_counter + 1

#         print(f'Processing record {counter} of {total}|' + response['name'])
        print(f'Processing record {idx_counter} of set {counter} |{city}')
       
    except KeyError:
        print(f'City not found. Skipping...')        
    pass



print(f'------------------------------------')          
print(f'Data Retrieval Complete')  
print(f'------------------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------------
# Processing record 1 of set 1 |rikitea
# Processing record 2 of set 1 |barrow
# Processing record 3 of set 1 |san francisco
# Processing record 4 of set 1 |ushuaia
# Processing record 5 of set 1 |saint-augustin
# Processing record 6 of set 1 |mount gambier
# Processing record 7 of set 1 |jamestown
# Processing record 8 of set 1 |castro
# Processing record 9 of set 1 |vestmanna
# Processing record 10 of set 1 |uvat
# Processing record 11 of set 1 |nantucket
# Processing record 12 of set 1 |tuktoyaktuk
# Processing record 13 of set 1 |butaritari
# Processing record 14 of set 1 |calvinia
# Processing record 15 of set 1 |east london
# Processing record 16 of set 1 |namatanai
# Processing record 17 of set 1 |pisco
# Processing record 18 of set 1 |dingle
# Processing record 19 of set 1 |saint george
# Processing record 20 of set 1 |vaini
# Processing record 21 of set 1 |acapulco
# Processing record 22 of set 1 |hermanus
# Processing record 23 of set 1 |alice springs
# Processing record 24 of set 1 |albany
# Processing record 25 of set 1 |zhanaozen
# Processing record 26 of set 1 |korla
# Processing record 27 of set 1 |mercedes
# Processing record 28 of set 1 |abbeville
# Processing record 29 of set 1 |cape town
# Processing record 30 of set 1 |mahoba
# Processing record 31 of set 1 |chuy
# Processing record 32 of set 1 |torata
# Processing record 33 of set 1 |predivinsk
# Processing record 34 of set 1 |isangel
# Processing record 35 of set 1 |ilulissat
# Processing record 36 of set 1 |nikolskoye
# Processing record 37 of set 1 |saldanha
# Processing record 38 of set 1 |lebu
# Processing record 39 of set 1 |chokurdakh
# Processing record 40 of set 1 |umm bab
# Processing record 41 of set 1 |batemans bay
# Processing record 42 of set 1 |nanortalik
# Processing record 43 of set 1 |thunder bay
# Processing record 44 of set 1 |constitucion
# Processing record 45 of set 1 |punta arenas
# Processing record 46 of set 1 |westport
# Processing record 47 of set 1 |guarabira
# Processing record 48 of set 1 |airai
# City not found. Skipping...
# Processing record 49 of set 1 |le port
# Processing record 50 of set 1 |beya
# Processing record 0 of set 2 |new norfolk
# Processing record 1 of set 2 |pansemal
# Processing record 2 of set 2 |georgetown
# Processing record 3 of set 2 |cairns
# Processing record 4 of set 2 |charleston
# Processing record 5 of set 2 |kapaa
# Processing record 6 of set 2 |mahebourg
# Processing record 7 of set 2 |puerto ayora
# Processing record 8 of set 2 |crotone
# Processing record 9 of set 2 |vardo
# Processing record 10 of set 2 |namibe
# Processing record 11 of set 2 |tiksi
# Processing record 12 of set 2 |guerrero negro
# Processing record 13 of set 2 |vila velha
# Processing record 14 of set 2 |hobart
# Processing record 15 of set 2 |matagami
# Processing record 16 of set 2 |dakar
# Processing record 17 of set 2 |port alfred
# Processing record 18 of set 2 |arraial do cabo
# Processing record 19 of set 2 |avera
# Processing record 20 of set 2 |zavodskoy
# Processing record 21 of set 2 |buraydah
# Processing record 22 of set 2 |dharampur
# City not found. Skipping...
# City not found. Skipping...
# Processing record 23 of set 2 |nome
# Processing record 24 of set 2 |ferrol
# Processing record 25 of set 2 |hobyo
# Processing record 26 of set 2 |cap-aux-meules
# Processing record 27 of set 2 |mar del plata
# Processing record 28 of set 2 |mataura
# Processing record 29 of set 2 |atuona
# City not found. Skipping...
# City not found. Skipping...
# Processing record 30 of set 2 |hilo
# Processing record 31 of set 2 |banjar
# Processing record 32 of set 2 |busselton
# Processing record 33 of set 2 |turayf
# Processing record 34 of set 2 |kilindoni
# City not found. Skipping...
# Processing record 35 of set 2 |bellegarde-sur-valserine
# Processing record 36 of set 2 |kagay
# Processing record 37 of set 2 |przasnysz
# Processing record 38 of set 2 |carmarthen
# Processing record 39 of set 2 |carnarvon
# Processing record 40 of set 2 |maceio
# City not found. Skipping...
# Processing record 41 of set 2 |preobrazheniye
# Processing record 42 of set 2 |hithadhoo
# Processing record 43 of set 2 |hukuntsi
# Processing record 44 of set 2 |pangody
# Processing record 45 of set 2 |victoria
# Processing record 46 of set 2 |coihaique
# Processing record 47 of set 2 |tokmak
# Processing record 48 of set 2 |camana
# Processing record 49 of set 2 |geraldton
# Processing record 50 of set 2 |sola
# Processing record 0 of set 3 |vanimo
# Processing record 1 of set 3 |saskylakh
# Processing record 2 of set 3 |san juan
# Processing record 3 of set 3 |lavrentiya
# Processing record 4 of set 3 |wyndham
# Processing record 5 of set 3 |longyearbyen
# Processing record 6 of set 3 |bredasdorp
# Processing record 7 of set 3 |satuk
# Processing record 8 of set 3 |muros
# Processing record 9 of set 3 |envira
# Processing record 10 of set 3 |kruisfontein
# Processing record 11 of set 3 |hasaki
# Processing record 12 of set 3 |mayo
# Processing record 13 of set 3 |dali
# Processing record 14 of set 3 |farafangana
# Processing record 15 of set 3 |oktyabrskiy
# Processing record 16 of set 3 |khatanga
# City not found. Skipping...
# City not found. Skipping...
# Processing record 17 of set 3 |faya
# Processing record 18 of set 3 |viedma
# Processing record 19 of set 3 |ribeira grande
# Processing record 20 of set 3 |port elizabeth
# Processing record 21 of set 3 |tairua
# Processing record 22 of set 3 |cockburn town
# Processing record 23 of set 3 |krishnarajpet
# Processing record 24 of set 3 |zonguldak
# City not found. Skipping...
# City not found. Skipping...
# Processing record 25 of set 3 |bairiki
# Processing record 26 of set 3 |bluff
# City not found. Skipping...
# Processing record 27 of set 3 |crixas
# Processing record 28 of set 3 |quatre cocos
# Processing record 29 of set 3 |komsomolskiy
# Processing record 30 of set 3 |xining
# Processing record 31 of set 3 |libreville
# Processing record 32 of set 3 |stykkisholmur
# Processing record 33 of set 3 |tasiilaq
# Processing record 34 of set 3 |unai
# Processing record 35 of set 3 |soyo
# Processing record 36 of set 3 |emerald
# Processing record 37 of set 3 |bayshore gardens
# Processing record 38 of set 3 |acarau
# Processing record 39 of set 3 |lerwick
# Processing record 40 of set 3 |maniitsoq
# Processing record 41 of set 3 |zhigansk
# Processing record 42 of set 3 |quang ngai
# Processing record 43 of set 3 |northam
# Processing record 44 of set 3 |nurota
# Processing record 45 of set 3 |comodoro rivadavia
# Processing record 46 of set 3 |karasburg
# Processing record 47 of set 3 |rawson
# City not found. Skipping...
# City not found. Skipping...
# Processing record 48 of set 3 |ballina
# Processing record 49 of set 3 |berkakit
# Processing record 50 of set 3 |drayton valley
# Processing record 0 of set 4 |padang
# Processing record 1 of set 4 |naze
# Processing record 2 of set 4 |weligama
# Processing record 3 of set 4 |kavaratti
# Processing record 4 of set 4 |dikson
# Processing record 5 of set 4 |tuatapere
# Processing record 6 of set 4 |mao
# Processing record 7 of set 4 |tupik
# Processing record 8 of set 4 |codrington
# Processing record 9 of set 4 |bata
# City not found. Skipping...
# Processing record 10 of set 4 |kodiak
# Processing record 11 of set 4 |aklavik
# Processing record 12 of set 4 |cacu
# City not found. Skipping...
# Processing record 13 of set 4 |broome
# Processing record 14 of set 4 |sabanalarga
# Processing record 15 of set 4 |phuket
# Processing record 16 of set 4 |luderitz
# Processing record 17 of set 4 |port lincoln
# Processing record 18 of set 4 |kaitangata
# Processing record 19 of set 4 |port-gentil
# Processing record 20 of set 4 |chicama
# Processing record 21 of set 4 |isabela
# Processing record 22 of set 4 |jackson
# Processing record 23 of set 4 |san quintin
# Processing record 24 of set 4 |maragogi
# Processing record 25 of set 4 |meadow lake
# Processing record 26 of set 4 |cherskiy
# Processing record 27 of set 4 |grand-santi
# Processing record 28 of set 4 |adrar
# Processing record 29 of set 4 |chumikan
# Processing record 30 of set 4 |carballo
# City not found. Skipping...
# Processing record 31 of set 4 |provideniya
# Processing record 32 of set 4 |micheweni
# Processing record 33 of set 4 |dalrymple
# City not found. Skipping...
# Processing record 34 of set 4 |naples
# Processing record 35 of set 4 |richards bay
# Processing record 36 of set 4 |thompson
# Processing record 37 of set 4 |severo-kurilsk
# Processing record 38 of set 4 |nenjiang
# Processing record 39 of set 4 |high level
# Processing record 40 of set 4 |klaksvik
# Processing record 41 of set 4 |san cristobal
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing record 42 of set 4 |qaanaaq
# Processing record 43 of set 4 |college
# Processing record 44 of set 4 |iwanai
# Processing record 45 of set 4 |ponta do sol
# Processing record 46 of set 4 |narsaq
# Processing record 47 of set 4 |aykhal
# Processing record 48 of set 4 |margate
# Processing record 49 of set 4 |santana do mundau
# Processing record 50 of set 4 |bathsheba
# Processing record 0 of set 5 |inhambane
# City not found. Skipping...
# Processing record 1 of set 5 |anapskaya
# Processing record 2 of set 5 |imbituba
# Processing record 3 of set 5 |bosaso
# Processing record 4 of set 5 |vestmannaeyjar
# Processing record 5 of set 5 |winnemucca
# Processing record 6 of set 5 |halifax
# Processing record 7 of set 5 |koutiala
# Processing record 8 of set 5 |yellowknife
# Processing record 9 of set 5 |leningradskiy
# City not found. Skipping...
# Processing record 10 of set 5 |newton stewart
# City not found. Skipping...
# Processing record 11 of set 5 |bambous virieux
# Processing record 12 of set 5 |pevek
# Processing record 13 of set 5 |saint-philippe
# Processing record 14 of set 5 |buchanan
# Processing record 15 of set 5 |ponta delgada
# Processing record 16 of set 5 |kez
# Processing record 17 of set 5 |marawi
# Processing record 18 of set 5 |cayenne
# Processing record 19 of set 5 |trincomalee
# Processing record 20 of set 5 |ilebo
# Processing record 21 of set 5 |wembley
# Processing record 22 of set 5 |laguna
# City not found. Skipping...
# Processing record 23 of set 5 |gurupa
# Processing record 24 of set 5 |gayny
# Processing record 25 of set 5 |grindavik
# Processing record 26 of set 5 |norman wells
# Processing record 27 of set 5 |esperance
# Processing record 28 of set 5 |loei
# Processing record 29 of set 5 |bulungu
# Processing record 30 of set 5 |oktyabrskoye
# Processing record 31 of set 5 |kieta
# Processing record 32 of set 5 |kot addu
# Processing record 33 of set 5 |teknaf
# Processing record 34 of set 5 |acari
# Processing record 35 of set 5 |samoded
# Processing record 36 of set 5 |north battleford
# Processing record 37 of set 5 |cidreira
# Processing record 38 of set 5 |ucluelet
# Processing record 39 of set 5 |chara
# Processing record 40 of set 5 |capitao poco
# Processing record 41 of set 5 |matay
# Processing record 42 of set 5 |san lorenzo de el escorial
# Processing record 43 of set 5 |porto velho
# Processing record 44 of set 5 |roma
# Processing record 45 of set 5 |henties bay
# City not found. Skipping...
# Processing record 46 of set 5 |abay
# Processing record 47 of set 5 |pierre
# Processing record 48 of set 5 |morgan city
# Processing record 49 of set 5 |samarai
# Processing record 50 of set 5 |panjakent
# City not found. Skipping...
# Processing record 0 of set 6 |saint-georges
# Processing record 1 of set 6 |san patricio
# City not found. Skipping...
# Processing record 2 of set 6 |gongzhuling
# Processing record 3 of set 6 |fairbanks
# Processing record 4 of set 6 |dunedin
# Processing record 5 of set 6 |visnes
# Processing record 6 of set 6 |visby
# Processing record 7 of set 6 |petropavlovsk-kamchatskiy
# Processing record 8 of set 6 |talnakh
# Processing record 9 of set 6 |lokosovo
# Processing record 10 of set 6 |balikpapan
# Processing record 11 of set 6 |kamenka
# Processing record 12 of set 6 |faanui
# Processing record 13 of set 6 |naryan-mar
# Processing record 14 of set 6 |kinna
# Processing record 15 of set 6 |chum phae
# Processing record 16 of set 6 |biltine
# Processing record 17 of set 6 |kavieng
# Processing record 18 of set 6 |chingirlau
# Processing record 19 of set 6 |konstantinovka
# Processing record 20 of set 6 |troitsko-pechorsk
# Processing record 21 of set 6 |dire dawa
# Processing record 22 of set 6 |durban
# Processing record 23 of set 6 |prince rupert
# Processing record 24 of set 6 |upernavik
# Processing record 25 of set 6 |bubaque
# Processing record 26 of set 6 |agbor
# Processing record 27 of set 6 |walvis bay
# Processing record 28 of set 6 |el astillero
# City not found. Skipping...
# Processing record 29 of set 6 |portland
# Processing record 30 of set 6 |iracoubo
# Processing record 31 of set 6 |flensburg
# Processing record 32 of set 6 |sao filipe
# Processing record 33 of set 6 |martapura
# Processing record 34 of set 6 |fare
# Processing record 35 of set 6 |gilgit
# Processing record 36 of set 6 |griffith
# Processing record 37 of set 6 |shache
# Processing record 38 of set 6 |the valley
# Processing record 39 of set 6 |suwannaphum
# Processing record 40 of set 6 |brae
# Processing record 41 of set 6 |barinas
# Processing record 42 of set 6 |bethel
# Processing record 43 of set 6 |mehamn
# Processing record 44 of set 6 |caimitillo
# Processing record 45 of set 6 |chapleau
# Processing record 46 of set 6 |erenhot
# Processing record 47 of set 6 |deputatskiy
# Processing record 48 of set 6 |labuhan
# Processing record 49 of set 6 |minab
# Processing record 50 of set 6 |kargala
# Processing record 0 of set 7 |tamandare
# Processing record 1 of set 7 |ketchikan
# Processing record 2 of set 7 |santa cruz del norte
# Processing record 3 of set 7 |verkhniy baskunchak
# Processing record 4 of set 7 |kahului
# Processing record 5 of set 7 |cicero dantas
# Processing record 6 of set 7 |katobu
# Processing record 7 of set 7 |santa helena de goias
# Processing record 8 of set 7 |fuyang
# Processing record 9 of set 7 |collie
# Processing record 10 of set 7 |avarua
# Processing record 11 of set 7 |mandera
# Processing record 12 of set 7 |bosanski novi
# Processing record 13 of set 7 |san matias
# Processing record 14 of set 7 |mokobeng
# Processing record 15 of set 7 |hollins
# Processing record 16 of set 7 |te anau
# Processing record 17 of set 7 |torbay
# Processing record 18 of set 7 |alofi
# Processing record 19 of set 7 |sotouboua
# Processing record 20 of set 7 |sanchor
# Processing record 21 of set 7 |port hedland
# Processing record 22 of set 7 |balaipungut
# Processing record 23 of set 7 |primo tapia
# Processing record 24 of set 7 |valkla
# Processing record 25 of set 7 |rehoboth
# Processing record 26 of set 7 |eyl
# Processing record 27 of set 7 |sena madureira
# City not found. Skipping...
# Processing record 28 of set 7 |mbour
# Processing record 29 of set 7 |evensk
# City not found. Skipping...
# Processing record 30 of set 7 |hofn
# Processing record 31 of set 7 |kazanka
# Processing record 32 of set 7 |hamilton
# Processing record 33 of set 7 |progreso
# Processing record 34 of set 7 |skibbereen
# Processing record 35 of set 7 |campbell river
# Processing record 36 of set 7 |bengkulu
# Processing record 37 of set 7 |mosquera
# Processing record 38 of set 7 |sept-iles
# Processing record 39 of set 7 |studena
# Processing record 40 of set 7 |betafo
# Processing record 41 of set 7 |salalah
# Processing record 42 of set 7 |falavarjan
# Processing record 43 of set 7 |chernoyerkovskaya
# Processing record 44 of set 7 |barda
# Processing record 45 of set 7 |date
# Processing record 46 of set 7 |miri
# Processing record 47 of set 7 |lorengau
# Processing record 48 of set 7 |yerofey pavlovich
# Processing record 49 of set 7 |darlowo
# Processing record 50 of set 7 |san vicente de canete
# Processing record 0 of set 8 |selfoss
# Processing record 1 of set 8 |alihe
# Processing record 2 of set 8 |yining
# Processing record 3 of set 8 |cheremukhovo
# Processing record 4 of set 8 |lake havasu city
# Processing record 5 of set 8 |katsuura
# Processing record 6 of set 8 |bridgewater
# Processing record 7 of set 8 |rio gallegos
# Processing record 8 of set 8 |labrea
# Processing record 9 of set 8 |puerto escondido
# Processing record 10 of set 8 |hay river
# Processing record 11 of set 8 |buala
# Processing record 12 of set 8 |ahuimanu
# City not found. Skipping...
# Processing record 13 of set 8 |bitung
# Processing record 14 of set 8 |nieuw amsterdam
# Processing record 15 of set 8 |puerto ayacucho
# Processing record 16 of set 8 |nouadhibou
# Processing record 17 of set 8 |lunenburg
# Processing record 18 of set 8 |kibakwe
# Processing record 19 of set 8 |jurmala
# Processing record 20 of set 8 |ferzikovo
# Processing record 21 of set 8 |mitsamiouli
# City not found. Skipping...
# Processing record 22 of set 8 |persianovskiy
# Processing record 23 of set 8 |atar
# Processing record 24 of set 8 |dalvik
# Processing record 25 of set 8 |placido de castro
# Processing record 26 of set 8 |paso de carrasco
# Processing record 27 of set 8 |umarkot
# City not found. Skipping...
# Processing record 28 of set 8 |mankono
# Processing record 29 of set 8 |seara
# Processing record 30 of set 8 |kaka
# Processing record 31 of set 8 |port hardy
# Processing record 32 of set 8 |saint-joseph
# Processing record 33 of set 8 |vostok
# Processing record 34 of set 8 |eureka
# Processing record 35 of set 8 |yar-sale
# Processing record 36 of set 8 |shenjiamen
# Processing record 37 of set 8 |goderich
# Processing record 38 of set 8 |kulhudhuffushi
# Processing record 39 of set 8 |sur
# Processing record 40 of set 8 |sinnamary
# Processing record 41 of set 8 |salinas
# Processing record 42 of set 8 |paragominas
# Processing record 43 of set 8 |inta
# Processing record 44 of set 8 |harrisonburg
# Processing record 45 of set 8 |svetlogorsk
# Processing record 46 of set 8 |port alberni
# Processing record 47 of set 8 |santa cruz de tenerife
# Processing record 48 of set 8 |saint anthony
# Processing record 49 of set 8 |moose factory
# Processing record 50 of set 8 |libourne
# Processing record 0 of set 9 |vanavara
# Processing record 1 of set 9 |khash
# Processing record 2 of set 9 |port shepstone
# Processing record 3 of set 9 |aksay
# Processing record 4 of set 9 |sao domingos
# Processing record 5 of set 9 |camacha
# Processing record 6 of set 9 |mangrol
# Processing record 7 of set 9 |chabahar
# Processing record 8 of set 9 |orsha
# Processing record 9 of set 9 |lagoa
# Processing record 10 of set 9 |imperatriz
# Processing record 11 of set 9 |abhar
# Processing record 12 of set 9 |yomou
# Processing record 13 of set 9 |olafsvik
# Processing record 14 of set 9 |mina
# Processing record 15 of set 9 |cabedelo
# Processing record 16 of set 9 |indiaroba
# Processing record 17 of set 9 |garissa
# Processing record 18 of set 9 |pacific grove
# Processing record 19 of set 9 |sistranda
# Processing record 20 of set 9 |tagusao
# Processing record 21 of set 9 |san ramon de la nueva oran
# Processing record 22 of set 9 |pitimbu
# Processing record 23 of set 9 |sambava
# Processing record 24 of set 9 |bay roberts
# Processing record 25 of set 9 |wattegama
# Processing record 26 of set 9 |qasigiannguit
# Processing record 27 of set 9 |tilichiki
# Processing record 28 of set 9 |pampas
# Processing record 29 of set 9 |biak
# Processing record 30 of set 9 |kassala
# Processing record 31 of set 9 |manitouwadge
# Processing record 32 of set 9 |idritsa
# Processing record 33 of set 9 |rawatsar
# Processing record 34 of set 9 |antsohihy
# Processing record 35 of set 9 |gravdal
# Processing record 36 of set 9 |gijon
# Processing record 37 of set 9 |iqaluit
# Processing record 38 of set 9 |xudat
# Processing record 39 of set 9 |boralday
# Processing record 40 of set 9 |bagdarin
# Processing record 41 of set 9 |estevan
# Processing record 42 of set 9 |bundaberg
# Processing record 43 of set 9 |ossora
# Processing record 44 of set 9 |baberu
# Processing record 45 of set 9 |sabha
# City not found. Skipping...
# Processing record 46 of set 9 |la asuncion
# Processing record 47 of set 9 |whitefish
# Processing record 48 of set 9 |buenos aires
# Processing record 49 of set 9 |fortuna
# Processing record 50 of set 9 |new amsterdam
# Processing record 0 of set 10 |kayerkan
# Processing record 1 of set 10 |calabozo
# Processing record 2 of set 10 |xuanhua
# Processing record 3 of set 10 |chifeng
# Processing record 4 of set 10 |merauke
# Processing record 5 of set 10 |vao
# Processing record 6 of set 10 |cabo san lucas
# Processing record 7 of set 10 |teya
# Processing record 8 of set 10 |iquique
# Processing record 9 of set 10 |santa cruz
# Processing record 10 of set 10 |port keats
# Processing record 11 of set 10 |trairi
# Processing record 12 of set 10 |finote selam
# Processing record 13 of set 10 |rocha
# Processing record 14 of set 10 |horia
# Processing record 15 of set 10 |el playon
# Processing record 16 of set 10 |alta gracia
# Processing record 17 of set 10 |tiznit
# Processing record 18 of set 10 |mantua
# Processing record 19 of set 10 |ducheng
# Processing record 20 of set 10 |bauchi
# Processing record 21 of set 10 |mezen
# Processing record 22 of set 10 |enzan
# Processing record 23 of set 10 |smithers
# Processing record 24 of set 10 |denpasar
# Processing record 25 of set 10 |maracacume
# Processing record 26 of set 10 |nemuro
# City not found. Skipping...
# Processing record 27 of set 10 |amapa
# Processing record 28 of set 10 |yuzhne
# City not found. Skipping...
# Processing record 29 of set 10 |kampot
# Processing record 30 of set 10 |roros
# City not found. Skipping...
# Processing record 31 of set 10 |belmonte
# Processing record 32 of set 10 |booue
# Processing record 33 of set 10 |jerusalem
# Processing record 34 of set 10 |mandalgovi
# Processing record 35 of set 10 |santo antonio de padua
# Processing record 36 of set 10 |chuari khas
# Processing record 37 of set 10 |kutum
# Processing record 38 of set 10 |dunmore town
# Processing record 39 of set 10 |apatity
# Processing record 40 of set 10 |kholodnyy
# City not found. Skipping...
# Processing record 41 of set 10 |kribi
# Processing record 42 of set 10 |kailua
# Processing record 43 of set 10 |helong
# Processing record 44 of set 10 |wanning
# Processing record 45 of set 10 |alvorada
# Processing record 46 of set 10 |boone
# Processing record 47 of set 10 |mersing
# Processing record 48 of set 10 |bangassou
# Processing record 49 of set 10 |asfi
# Processing record 50 of set 10 |mount isa
# Processing record 0 of set 11 |oranjestad
# Processing record 1 of set 11 |inirida
# Processing record 2 of set 11 |ust-tsilma
# Processing record 3 of set 11 |cap malheureux
# Processing record 4 of set 11 |katangli
# Processing record 5 of set 11 |edgewater
# Processing record 6 of set 11 |altamont
# Processing record 7 of set 11 |fethiye
# Processing record 8 of set 11 |marsabit
# Processing record 9 of set 11 |monteagudo
# Processing record 10 of set 11 |souillac
# Processing record 11 of set 11 |omsukchan
# Processing record 12 of set 11 |makakilo city
# Processing record 13 of set 11 |meulaboh
# Processing record 14 of set 11 |lucapa
# Processing record 15 of set 11 |zelenogorskiy
# Processing record 16 of set 11 |hualmay
# Processing record 17 of set 11 |borogontsy
# City not found. Skipping...
# Processing record 18 of set 11 |massakory
# Processing record 19 of set 11 |aksu
# Processing record 20 of set 11 |tabou
# Processing record 21 of set 11 |fayaoue
# Processing record 22 of set 11 |yamada
# Processing record 23 of set 11 |mecca
# Processing record 24 of set 11 |talaya
# City not found. Skipping...
# Processing record 25 of set 11 |basqal
# Processing record 26 of set 11 |kisaran
# Processing record 27 of set 11 |dukat
# Processing record 28 of set 11 |kitimat
# Processing record 29 of set 11 |clyde river
# Processing record 30 of set 11 |tomatlan
# Processing record 31 of set 11 |kozhva
# Processing record 32 of set 11 |ilhabela
# Processing record 33 of set 11 |hue
# Processing record 34 of set 11 |howard springs
# Processing record 35 of set 11 |salcininkai
# Processing record 36 of set 11 |alyangula
# Processing record 37 of set 11 |taksimo
# Processing record 38 of set 11 |grand gaube
# Processing record 39 of set 11 |san juan bautista
# Processing record 40 of set 11 |atyrau
# Processing record 41 of set 11 |vilhena
# Processing record 42 of set 11 |boden
# Processing record 43 of set 11 |nizhniy tsasuchey
# Processing record 44 of set 11 |yantal
# Processing record 45 of set 11 |bulawayo
# Processing record 46 of set 11 |sogne
# Processing record 47 of set 11 |praia da vitoria
# Processing record 48 of set 11 |tecoanapa
# Processing record 49 of set 11 |kununurra
# Processing record 50 of set 11 |umea
# Processing record 0 of set 12 |berezovyy
# Processing record 1 of set 12 |newport
# Processing record 2 of set 12 |shingu
# Processing record 3 of set 12 |ancud
# Processing record 4 of set 12 |half moon bay
# Processing record 5 of set 12 |gazanjyk
# Processing record 6 of set 12 |plomarion
# Processing record 7 of set 12 |kandiari
# City not found. Skipping...
# Processing record 8 of set 12 |langsa
# Processing record 9 of set 12 |la merced
# Processing record 10 of set 12 |itajai
# City not found. Skipping...
# City not found. Skipping...
# Processing record 11 of set 12 |wewak
# Processing record 12 of set 12 |sioux lookout
# City not found. Skipping...
# Processing record 13 of set 12 |yashkul
# Processing record 14 of set 12 |kanye
# Processing record 15 of set 12 |sakakah
# Processing record 16 of set 12 |tezu
# Processing record 17 of set 12 |flin flon
# Processing record 18 of set 12 |baykit
# Processing record 19 of set 12 |sitka
# Processing record 20 of set 12 |tabory
# Processing record 21 of set 12 |poum
# Processing record 22 of set 12 |hoopstad
# ------------------------------------
# Data Retrieval Complete
# ------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = {
    "City": City,
    "Lat": Lat,
    "Lng": Lng,
    "Max Temp":Max_Temp,
    "Humidity": Humidity,
    "Cloudiness":Cloudiness,
    "Wind Speed":Wind_Speed,
    "Country":Country,
    "Date":Date}
weather_data = pd.DataFrame(data)
weather_data.head()
weather_data.to_csv('weather_data.csv')
weather_data.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
weather_data.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Rikitea -23.12 -134.97     71.65        69          66       18.03
# 1          Barrow  71.29 -156.79     51.80        76           1       10.29
# 2   San Francisco  37.77 -122.42     69.80        64          20       20.80
# 3         Ushuaia -54.80  -68.30     33.80        86          90       12.75
# 4  Saint-Augustin  51.23  -58.65     65.79        91          72       18.61
#
#   Country        Date
# 0      PF  1597190676
# 1      US  1597190562
# 2      US  1597190676
# 3      AR  1597190529
# 4      CA  1597190676

# %%
# city_data = weather_data[weather_data["City"] == 'San Francisco']
# city_data

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  583.000000  583.000000  583.000000  583.000000  583.000000  583.000000
# mean    20.885129   14.329623   68.184460   72.082333   47.161235    7.534854
# std     33.090337   88.425170   13.427704   19.291579   36.858717    5.105727
# min    -54.800000 -175.200000   33.800000    1.000000    0.000000    0.200000
# 25%     -7.385000  -63.115000   58.945000   62.000000    8.000000    3.635000
# 50%     25.500000   18.750000   70.000000   77.000000   43.000000    6.310000
# 75%     49.185000   86.575000   78.755000   86.000000   78.500000   10.290000
# max     78.220000  178.420000  109.990000  100.000000  100.000000   29.970000
#
#                Date
# count  5.830000e+02
# mean   1.597191e+09
# std    8.264141e+01
# min    1.597190e+09
# 25%    1.597191e+09
# 50%    1.597191e+09
# 75%    1.597191e+09
# max    1.597191e+09

# %%
#  Get the indices of cities that have humidity over 100%.
humidity = weather_data[weather_data['Humidity']>100].index
humidity
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data
clean_city_data
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.80  -68.30     41.00        56          75       18.34
# 1     Hastings  50.86    0.57     81.00        65         100       12.75
# 2     Cidreira -30.18  -50.21     67.30        59           0        6.31
# 3        Natal  -5.79  -35.21     84.20        62          75       21.92
# 4    Busselton -33.65  115.33     55.99        71          73       17.27
# ..         ...    ...     ...       ...       ...         ...         ...
# 544    Kaabong   3.48   34.15     64.24        86          44        5.08
# 545    Honiara  -9.43  159.95     73.40        94          40        3.36
# 546   Chimbote  -9.09  -78.58     65.23        71          20       10.89
# 547    Pachino  36.72   15.09     81.00        72           0        1.97
# 548      Kyzyl  51.70   94.45     59.92        61           0        3.40
#
#     Country        Date
# 0        AR  1596997801
# 1        GB  1596997802
# 2        BR  1596997577
# 3        BR  1596997803
# 4        AU  1596997803
# ..      ...         ...
# 544      UG  1596997987
# 545      SB  1596997987
# 546      PE  1596997987
# 547      IT  1596997988
# 548      RU  1596997988
#
# [549 rows x 9 columns]

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv
clean_city_data.to_csv('clean_city_data.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"], marker="o", edgecolors='black')

plt.title("City Latitude vs Max Temperature (8/11/20)")
plt.ylabel("Max Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../saved_figures/lat_vs_maxtemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"], marker="o", edgecolors='black')

plt.title("City Latitude vs Humidity (8/11/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../saved_figures/lat_vs_humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"], marker="o", edgecolors='black')

plt.title("City Latitude vs Cloudiness (8/11/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../saved_figures/lat_vs_cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"], marker="o", edgecolors='black')

plt.title("City Latitude vs Wind Speed (8/11/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("../saved_figures/lat_vs_windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def line_reg(x_values,y_values, title, xlabel, ylabel):
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    
    print(f"The r-squared is: {r_value**2}")
    plt.scatter(x_values,y_values, label="fitted line")
    plt.plot(x_values,regress_values,"r-")
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return line_eq
 
def annotate(line_eq, a,b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
north = clean_city_data.loc[weather_data['Lat'] >= 0]
south = clean_city_data.loc[weather_data['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_scatter = line_reg(north['Lat'], north['Max Temp'],'Northern Hemisphere - Max Temp vs Latitude Linear Regression','Latitude', 'Max Temp')
annotate(north_scatter,0,40)
plt.savefig("../saved_figures/northernhem_maxtemp_vs_lat.png")
# Out:
# The r-squared is: 5.2234636047296864e-05

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_scatter = line_reg(south['Lat'], south['Max Temp'],'Southern Hemisphere - Max Temp vs Latitude Linear Regression','Latitude', 'Max Temp')
annotate(south_scatter,-30,40)
plt.savefig("../saved_figures/southern_hem_maxtemp_vs_lat.png")
# Out:
# The r-squared is: 0.040948363543608125

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_humidity = line_reg(north['Lat'], north['Humidity'],'Northern Hemisphere - Humidity(%) vs Latitude Linear Regression','Latitude', 'Humidity')
annotate(n_humidity,45,20)
plt.savefig("../saved_figures/northern_hem_humidity_vs_lat.png")
# Out:
# The r-squared is: 0.0009240053966584844

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_humidity = line_reg(south['Lat'], south['Humidity'],'Southern Hemisphere - Humidity(%) vs Latitude Linear Regression','Latitude', 'Humidity')
annotate(s_humidity, -50,20)
plt.savefig("../saved_figures/southern_hem_humidity_vs_lat.png")
# Out:
# The r-squared is: 0.009824072939809535

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_cloudiness = line_reg(north['Lat'], north['Cloudiness'],'Northern Hemisphere - Cloudiness(%) vs Latitude Linear Regression','Latitude', 'Cloudiness')
annotate(n_cloudiness, 40,30)
plt.savefig("../saved_figures/northern_hem_cloudiness_vs_lat.png")
# Out:
# The r-squared is: 0.0012195507224001612

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_cloudiness = line_reg(south['Lat'], south['Cloudiness'],'Southern Hemisphere - Cloudiness(%) vs Latitude Linear Regression','Latitude', 'Cloudiness')
annotate(n_cloudiness, -50,25)
plt.savefig("../saved_figures/southern_hem_cloudiness_vs_lat.png")
# Out:
# The r-squared is: 0.015740220174478552

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_windspeed = line_reg(north['Lat'], north['Wind Speed'],'Northern Hemisphere - Wind Speed(mph) vs Latitude Linear Regression','Latitude', 'Wind Speed')
annotate(n_windspeed, 25,25)
plt.savefig("../saved_figures/northern_hem_windspeed_vs_lat.png")
# Out:
# The r-squared is: 0.002379106260823132

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_windspeed = line_reg(south['Lat'], south['Wind Speed'],'Southern Hemisphere - Wind Speed(mph) vs Latitude Linear Regression','Latitude', 'Wind Speed')
annotate(s_windspeed, -40,25)
plt.savefig("../saved_figures/southern_hem_windspeed_vs_lat.png")
# Out:
# The r-squared is: 0.015020711081756895
